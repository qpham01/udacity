# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.
# Downloading data from http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170450944/170498071 [============================>.] - ETA: 0s

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
# Epoch 00000: val_loss improved from inf to 1.27394, saving model to model.weights.best.hdf5
# 8s - loss: 1.5958 - acc: 0.4242 - val_loss: 1.2739 - val_acc: 0.5430
# Epoch 2/100
# Epoch 00001: val_loss did not improve
# 6s - loss: 1.2799 - acc: 0.5426 - val_loss: 1.2844 - val_acc: 0.5458
# Epoch 3/100
# Epoch 00002: val_loss improved from 1.27394 to 1.08388, saving model to model.weights.best.hdf5
# 6s - loss: 1.1591 - acc: 0.5882 - val_loss: 1.0839 - val_acc: 0.6088
# Epoch 4/100
# Epoch 00003: val_loss did not improve
# 6s - loss: 1.0851 - acc: 0.6170 - val_loss: 1.1898 - val_acc: 0.6006
# Epoch 5/100
# Epoch 00004: val_loss improved from 1.08388 to 0.96401, saving model to model.weights.best.hdf5
# 6s - loss: 1.0479 - acc: 0.6341 - val_loss: 0.9640 - val_acc: 0.6694
# Epoch 6/100
# Epoch 00005: val_loss improved from 0.96401 to 0.93561, saving model to model.weights.best.hdf5
# 6s - loss: 1.0211 - acc: 0.6455 - val_loss: 0.9356 - val_acc: 0.6826
# Epoch 7/100
# Epoch 00006: val_loss did not improve
# 6s - loss: 1.0072 - acc: 0.6518 - val_loss: 1.0985 - val_acc: 0.6226
# Epoch 8/100
# Epoch 00007: val_loss did not improve
# 6s - loss: 1.0058 - acc: 0.6560 - val_loss: 0.9925 - val_acc: 0.6732
# Epoch 9/100
# Epoch 00008: val_loss improved from 0.93561 to 0.90700, saving model to model.weights.best.hdf5
# 6s - loss: 1.0067 - acc: 0.6613 - val_loss: 0.9070 - val_acc: 0.6882
# Epoch 10/100
# Epoch 00009: val_loss did not improve
# 6s - loss: 1.0124 - acc: 0.6586 - val_loss: 1.0630 - val_acc: 0.6406
# Epoch 11/100
# Epoch 00010: val_loss did not improve
# 6s - loss: 1.0217 - acc: 0.6551 - val_loss: 1.4806 - val_acc: 0.5894
# Epoch 12/100
# Epoch 00011: val_loss did not improve
# 6s - loss: 1.0414 - acc: 0.6535 - val_loss: 1.2382 - val_acc: 0.6020
# Epoch 13/100
# Epoch 00012: val_loss did not improve
# 6s - loss: 1.0474 - acc: 0.6510 - val_loss: 0.9794 - val_acc: 0.6704
# Epoch 14/100
# Epoch 00013: val_loss did not improve
# 6s - loss: 1.0685 - acc: 0.6469 - val_loss: 1.2495 - val_acc: 0.5984
# Epoch 15/100
# Epoch 00014: val_loss did not improve
# 6s - loss: 1.0926 - acc: 0.6365 - val_loss: 1.0061 - val_acc: 0.6624
# Epoch 16/100
# Epoch 00015: val_loss did not improve
# 6s - loss: 1.1032 - acc: 0.6370 - val_loss: 1.5296 - val_acc: 0.5516
# Epoch 17/100
# Epoch 00016: val_loss did not improve
# 6s - loss: 1.1258 - acc: 0.6291 - val_loss: 0.9949 - val_acc: 0.6788
# Epoch 18/100
# Epoch 00017: val_loss did not improve
# 6s - loss: 1.1501 - acc: 0.6214 - val_loss: 1.1300 - val_acc: 0.6248
# Epoch 19/100
# Epoch 00018: val_loss did not improve
# 6s - loss: 1.1800 - acc: 0.6129 - val_loss: 1.1938 - val_acc: 0.5950
# Epoch 20/100
# Epoch 00019: val_loss did not improve
# 6s - loss: 1.2065 - acc: 0.5999 - val_loss: 1.0449 - val_acc: 0.6568
# Epoch 21/100
# Epoch 00020: val_loss did not improve
# 6s - loss: 1.2202 - acc: 0.5985 - val_loss: 1.7318 - val_acc: 0.5154
# Epoch 22/100
# Epoch 00021: val_loss did not improve
# 6s - loss: 1.2328 - acc: 0.5910 - val_loss: 1.3733 - val_acc: 0.5618
# Epoch 23/100
# Epoch 00022: val_loss did not improve
# 6s - loss: 1.2412 - acc: 0.5921 - val_loss: 1.3849 - val_acc: 0.4984
# Epoch 24/100
# Epoch 00023: val_loss did not improve
# 6s - loss: 1.2770 - acc: 0.5792 - val_loss: 1.3857 - val_acc: 0.6198
# Epoch 25/100
# Epoch 00024: val_loss did not improve
# 6s - loss: 1.3019 - acc: 0.5724 - val_loss: 1.0735 - val_acc: 0.6428
# Epoch 26/100
# Epoch 00025: val_loss did not improve
# 6s - loss: 1.3183 - acc: 0.5691 - val_loss: 1.2295 - val_acc: 0.6038
# Epoch 27/100
# Epoch 00026: val_loss did not improve
# 6s - loss: 1.3248 - acc: 0.5644 - val_loss: 1.6851 - val_acc: 0.5676
# Epoch 28/100
# Epoch 00027: val_loss did not improve
# 6s - loss: 1.3518 - acc: 0.5530 - val_loss: 1.4273 - val_acc: 0.5450
# Epoch 29/100
# Epoch 00028: val_loss did not improve
# 6s - loss: 1.3616 - acc: 0.5514 - val_loss: 1.0828 - val_acc: 0.6462
# Epoch 30/100
# Epoch 00029: val_loss did not improve
# 6s - loss: 1.3794 - acc: 0.5446 - val_loss: 1.1567 - val_acc: 0.6152
# Epoch 31/100
# Epoch 00030: val_loss did not improve
# 6s - loss: 1.3902 - acc: 0.5403 - val_loss: 1.4778 - val_acc: 0.4442
# Epoch 32/100
# Epoch 00031: val_loss did not improve
# 6s - loss: 1.4045 - acc: 0.5392 - val_loss: 1.1755 - val_acc: 0.6020
# Epoch 33/100
# Epoch 00032: val_loss did not improve
# 6s - loss: 1.4241 - acc: 0.5287 - val_loss: 1.3221 - val_acc: 0.5530
# Epoch 34/100
# Epoch 00033: val_loss did not improve
# 6s - loss: 1.4426 - acc: 0.5196 - val_loss: 1.7493 - val_acc: 0.5000
# Epoch 35/100
# Epoch 00034: val_loss did not improve
# 6s - loss: 1.4472 - acc: 0.5188 - val_loss: 1.4647 - val_acc: 0.4738
# Epoch 36/100
# Epoch 00035: val_loss did not improve
# 6s - loss: 1.4724 - acc: 0.5098 - val_loss: 1.2175 - val_acc: 0.5740
# Epoch 37/100
# Epoch 00036: val_loss did not improve
# 6s - loss: 1.4886 - acc: 0.5024 - val_loss: 1.4332 - val_acc: 0.5026
# Epoch 38/100
# Epoch 00037: val_loss did not improve
# 6s - loss: 1.5090 - acc: 0.4945 - val_loss: 1.4771 - val_acc: 0.4832
# Epoch 39/100
# Epoch 00038: val_loss did not improve
# 6s - loss: 1.5214 - acc: 0.4940 - val_loss: 1.3780 - val_acc: 0.5412
# Epoch 40/100
# Epoch 00039: val_loss did not improve
# 6s - loss: 1.5237 - acc: 0.4883 - val_loss: 1.6729 - val_acc: 0.5344
# Epoch 41/100
# Epoch 00040: val_loss did not improve
# 6s - loss: 1.5390 - acc: 0.4828 - val_loss: 1.3937 - val_acc: 0.5232
# Epoch 42/100
# Epoch 00041: val_loss did not improve
# 6s - loss: 1.5433 - acc: 0.4803 - val_loss: 1.4338 - val_acc: 0.4960
# Epoch 43/100
# Epoch 00042: val_loss did not improve
# 6s - loss: 1.5494 - acc: 0.4724 - val_loss: 1.5294 - val_acc: 0.4600
# Epoch 44/100
# Epoch 00043: val_loss did not improve
# 6s - loss: 1.5637 - acc: 0.4688 - val_loss: 1.5606 - val_acc: 0.5180
# Epoch 45/100
# 6s - loss: 1.8117 - acc: 0.3682 - val_loss: 1.7219 - val_acc: 0.3814
# Epoch 88/100
# Epoch 00087: val_loss did not improve
# 6s - loss: 1.7999 - acc: 0.3713 - val_loss: 2.0970 - val_acc: 0.3318
# Epoch 89/100
# Epoch 00088: val_loss did not improve
# 6s - loss: 1.8146 - acc: 0.3678 - val_loss: 1.6111 - val_acc: 0.4260
# Epoch 90/100
# Epoch 00089: val_loss did not improve
# 6s - loss: 1.8007 - acc: 0.3682 - val_loss: 1.5565 - val_acc: 0.4198
# Epoch 91/100
# Epoch 00090: val_loss did not improve
# 6s - loss: 1.8108 - acc: 0.3644 - val_loss: 1.5769 - val_acc: 0.4460
# Epoch 92/100
# Epoch 00091: val_loss did not improve
# 6s - loss: 1.8132 - acc: 0.3620 - val_loss: 1.5547 - val_acc: 0.4360
# Epoch 93/100
# Epoch 00092: val_loss did not improve
# 6s - loss: 1.8132 - acc: 0.3620 - val_loss: 1.6350 - val_acc: 0.4146
# Epoch 94/100
# Epoch 00093: val_loss did not improve
# 6s - loss: 1.8096 - acc: 0.3666 - val_loss: 1.5772 - val_acc: 0.4090
# Epoch 95/100
# Epoch 00094: val_loss did not improve
# 6s - loss: 1.8180 - acc: 0.3610 - val_loss: 1.5105 - val_acc: 0.4456
# Epoch 96/100
# Epoch 00095: val_loss did not improve
# 6s - loss: 1.8161 - acc: 0.3572 - val_loss: 1.5714 - val_acc: 0.4322
# Epoch 97/100
# Epoch 00096: val_loss did not improve
# 6s - loss: 1.8205 - acc: 0.3645 - val_loss: 5.4583 - val_acc: 0.2830
# Epoch 98/100
# Epoch 00097: val_loss did not improve
# 6s - loss: 1.8296 - acc: 0.3619 - val_loss: 1.5116 - val_acc: 0.4284
# Epoch 99/100
# Epoch 00098: val_loss did not improve
# 6s - loss: 1.8370 - acc: 0.3541 - val_loss: 1.7577 - val_acc: 0.3950
# Epoch 100/100
# Epoch 00099: val_loss did not improve
# 6s - loss: 1.8214 - acc: 0.3554 - val_loss: 1.6257 - val_acc: 0.4216

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6788

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
