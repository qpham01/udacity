# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-3
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count / total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold / freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() > p_drop[word]]
drop_count = total_count - len(train_words)
print('Subsampling dropped {} words out of {} words ({:.2f}%)'.format(drop_count, total_count, 100 * drop_count / total_count))
# Out:
# Subsampling dropped 5021012 words out of 16680599 words (30.10%)

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    rand = np.random.randint(1, window_size + 1)
    start = max(0, idx - rand)
    end = min(len(words), idx + rand + 1)
    targets = set(words[start:idx] + words[idx + 1:end])
    
    return list(targets) # , rand

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# A subdirectory or file checkpoints already exists.

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 7.2273 0.1536 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 7.1130 0.1474 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 6.9862 0.1493 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 6.7076 0.1498 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 6.3761 0.1525 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.9945 0.1535 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.7020 0.1526 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.4825 0.1550 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4982 0.1559 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3782 0.1572 sec/batch
# Nearest to over: point, valley, avatar, kill, heavy, connections, is, abdal,
# Nearest to this: mehmed, aa, given, fights, manifestations, landing, defense, paolo,
# Nearest to s: samuel, highlights, union, prehistoric, string, lent, census, threw,
# Nearest to with: what, frequencies, scrolls, gte, god, wheat, invaders, old,
# Nearest to first: conformational, concave, did, tapwave, bratislava, account, practice, verbal,
# Nearest to zero: edition, valleys, camden, controversial, pay, reason, pathways, below,
# Nearest to their: conservative, nster, suri, having, personality, provide, viii, you,
# Nearest to may: himself, lesotho, hani, westernmost, lost, phrasing, ashton, case,
# Nearest to recorded: star, represented, istanbul, remainder, speakers, studied, qualifications, perturbed,
# Nearest to award: gotha, nazis, native, intruders, unwelcome, mad, citadel, undeciphered,
# Nearest to paris: very, concerns, christianity, ticketing, collection, replay, email, literals,
# Nearest to pope: vienna, meters, talib, surveys, gas, flint, pseudo, squandered,
# Nearest to engineering: kum, mujibur, admittedly, difficult, organization, loudly, cellphones, unlocking,
# Nearest to shown: arms, subsidence, distribution, lead, isshu, union, messiah, absolutely,
# Nearest to pressure: policy, been, block, hands, pure, poles, workers, benefit,
# Nearest to institute: kyd, marseille, appealed, belgica, industry, saint, hopkins, absinth,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.2779 0.1573 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.2545 0.1529 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.1565 0.1517 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.1426 0.1522 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1015 0.1546 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.0923 0.1540 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.9876 0.1554 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0463 0.1578 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0167 0.1564 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9872 0.1547 sec/batch
# Nearest to over: avatar, heavy, donna, kill, point, antenna, valley, successive,
# Nearest to this: mehmed, aa, fights, manifestations, landing, given, paolo, kr,
# Nearest to s: samuel, union, highlights, lent, string, prehistoric, threw, worthington,
# Nearest to with: frequencies, residential, wheat, scrolls, what, invaders, appearing, gte,
# Nearest to first: conformational, bratislava, super, concave, atoms, achievements, tapwave, camden,
# Nearest to zero: edition, camden, amd, valleys, pathways, october, mega, controversial,
# Nearest to their: conservative, provide, nster, personality, boundary, amstrad, packs, suri,
# Nearest to may: westernmost, hoax, hani, teams, beverage, himself, lesotho, ashton,
# Nearest to recorded: studied, qualifications, vcs, istanbul, star, represented, remainder, speakers,
# Nearest to award: crucial, nazis, citadel, intruders, unwelcome, mad, eve, gotha,
# Nearest to paris: aerial, concerns, very, replay, ticketing, christianity, fishing, workmen,
# Nearest to pope: talib, vienna, meters, federation, surveys, flint, gas, calcium,
# Nearest to engineering: kum, mujibur, admittedly, cellphones, difficult, accusing, dropping, waldo,
# Nearest to shown: subsidence, absolutely, battlefield, arms, isshu, pasha, lead, messiah,
# Nearest to pressure: policy, block, been, televisions, pure, hands, aquaria, inscription,
# Nearest to institute: kyd, hopkins, appealed, marseille, belgica, saint, delhi, institutions,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9476 0.1560 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8744 0.1576 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9086 0.1546 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.9425 0.1583 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8912 0.1577 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.9065 0.1559 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8489 0.1559 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8187 0.1560 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7400 0.1574 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8554 0.1576 sec/batch
# Nearest to over: avatar, heavy, donna, antenna, kill, point, steadily, potentials,
# Nearest to this: mehmed, fights, manifestations, aa, given, genes, mohenjo, paolo,
# Nearest to s: samuel, union, highlights, lent, rioters, vp, prehistoric, gg,
# Nearest to with: frequencies, residential, what, wheat, scrolls, overwhelmingly, scan, gte,
# Nearest to first: conformational, bratislava, atoms, super, camden, concave, achievements, continual,
# Nearest to zero: edition, camden, october, amd, valleys, pathways, est, mega,
# Nearest to their: conservative, piggy, personality, provide, amstrad, having, do, boundary,
# Nearest to may: hoax, hani, lesotho, ashton, beverage, harsh, phrasing, analyzer,
# Nearest to recorded: qualifications, studied, vcs, star, nomination, istanbul, remainder, represented,
# Nearest to award: intruders, citadel, unwelcome, crucial, nazis, fern, eve, mad,
# Nearest to paris: aerial, ticketing, concerns, replay, devon, workmen, fishing, christianity,
# Nearest to pope: talib, vienna, federation, squandered, surveys, meters, flint, kabbalah,
# Nearest to engineering: kum, mujibur, admittedly, cellphones, loudly, espionage, accusing, waldo,
# Nearest to shown: subsidence, isshu, battlefield, zapata, absolutely, pasha, arms, messiah,
# Nearest to pressure: policy, block, inscription, pure, aquaria, televisions, benefit, conveniently,
# Nearest to institute: kyd, hopkins, marseille, belgica, delhi, institutions, canterbury, industry,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8211 0.1586 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7929 0.1572 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7949 0.1546 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.8033 0.1438 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7535 0.1386 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.8261 0.1365 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7836 0.1374 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7586 0.1389 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7780 0.1370 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.7397 0.1368 sec/batch
# Nearest to over: antenna, avatar, heavy, kill, donna, steadily, gaussian, seeing,
# Nearest to this: mehmed, manifestations, fights, landing, tutor, mohenjo, simple, given,
# Nearest to s: samuel, lent, highlights, vp, worthington, rioters, union, prehistoric,
# Nearest to with: frequencies, residential, what, wheat, adults, scrolls, scan, gte,
# Nearest to first: super, conformational, bratislava, northward, heartfelt, medusa, concave, achievements,
# Nearest to zero: edition, october, camden, amd, february, mega, valleys, males,
# Nearest to their: conservative, having, personality, amstrad, piggy, do, likely, provide,
# Nearest to may: hoax, hani, ashton, fragrance, case, harsh, analyzer, connie,
# Nearest to recorded: qualifications, studied, vcs, star, perturbed, istanbul, apology, unattended,
# Nearest to award: intruders, fern, unwelcome, citadel, edition, mad, eve, crucial,
# Nearest to paris: replay, aerial, workmen, devon, ticketing, concerns, crowned, literals,
# Nearest to pope: talib, vienna, kabbalah, federation, squandered, meters, surveys, despatch,
# Nearest to engineering: kum, mujibur, admittedly, cellphones, loudly, waldo, compositional, espionage,
# Nearest to shown: subsidence, pasha, zapata, battlefield, isshu, leszek, bose, bartenders,
# Nearest to pressure: policy, block, pure, conveniently, regimen, scratching, aquaria, metabolism,
# Nearest to institute: kyd, hopkins, canterbury, belgica, ineffectiveness, institutions, gamemaster, delhi,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.7464 0.1383 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.7736 0.1378 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.7314 0.1394 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.7422 0.1392 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6881 0.1379 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.7354 0.1380 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 4.7441 0.1391 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 4.7062 0.1392 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 4.7463 0.1391 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 4.7003 0.1376 sec/batch
# Nearest to over: antenna, heavy, donna, kill, avatar, potentials, gaussian, berimbau,
# Nearest to this: mehmed, fights, manifestations, mohenjo, given, genes, it, grassy,
# Nearest to s: samuel, rioters, highlights, worthington, vp, lent, birthday, shakespearean,
# Nearest to with: frequencies, residential, wheat, what, adults, emmer, photographs, appearing,
# Nearest to first: super, camden, bratislava, conformational, trophies, medusa, supplemental, achievements,
# Nearest to zero: edition, october, camden, amd, trey, mega, february, alison,
# Nearest to their: began, having, amstrad, personality, piggy, palatable, do, neurons,
# Nearest to may: hoax, hani, fragrance, representable, ashton, deanna, analyzer, case,
# Nearest to recorded: studied, qualifications, star, vcs, perturbed, nomination, unattended, istanbul,
# Nearest to award: intruders, fern, unwelcome, mad, citadel, pronouncing, eve, gotha,
# Nearest to paris: aerial, devon, replay, ticketing, workmen, crowned, muzio, cot,
# Nearest to pope: talib, vienna, federation, kabbalah, squandered, despatch, tandy, cripps,
# Nearest to engineering: kum, mujibur, cellphones, admittedly, compositional, waldo, dhimma, loudly,
# Nearest to shown: subsidence, zapata, pasha, bartenders, absolutely, fn, bose, battlefield,
# Nearest to pressure: policy, scratching, pure, metabolism, block, conveniently, regimen, unpleasant,
# Nearest to institute: kyd, hopkins, ineffectiveness, gamemaster, canterbury, belgica, institutions, delhi,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 4.6298 0.1394 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 4.7047 0.1424 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 4.6527 0.1422 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 4.6934 0.1426 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 4.6989 0.1434 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 4.6779 0.1441 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 4.6834 0.1428 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 4.6422 0.1445 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 4.6718 0.1438 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 4.6261 0.1418 sec/batch
# Nearest to over: antenna, heavy, avatar, donna, gaussian, kill, abdal, tocantins,
# Nearest to this: mehmed, fights, manifestations, mohenjo, it, given, grassy, mediocrity,
# Nearest to s: samuel, rioters, vp, lent, worthington, highlights, inspirations, neuroscientists,
# Nearest to with: frequencies, residential, emmer, wheat, prompting, scan, photographs, what,
# Nearest to first: super, flavorings, bratislava, supplemental, tycoon, concave, medusa, camden,
# Nearest to zero: edition, october, camden, est, alison, trey, three, mega,
# Nearest to their: began, amstrad, piggy, having, personality, do, palatable, conservative,
# Nearest to may: representable, phrasing, hoax, ashton, fragrance, deanna, vehicles, case,
# Nearest to recorded: qualifications, star, vcs, studied, nomination, perturbed, unattended, tryin,
# Nearest to award: fern, intruders, unwelcome, best, eve, mad, undeciphered, senka,
# Nearest to paris: aerial, devon, ticketing, workmen, crowned, muzio, replay, vinge,
# Nearest to pope: talib, vienna, squandered, federation, kabbalah, evokes, cripps, despatch,
# Nearest to engineering: cellphones, kum, admittedly, mujibur, compositional, defintion, espionage, dhimma,
# Nearest to shown: subsidence, zapata, bartenders, isshu, pasha, damn, hailstorm, bose,
# Nearest to pressure: policy, scratching, pure, metabolism, regimen, conveniently, block, quantity,
# Nearest to institute: kyd, hopkins, gamemaster, ineffectiveness, institutions, moreno, belgica, canterbury,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 4.6509 0.1415 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 4.6473 0.1402 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 4.6532 0.1425 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 4.6568 0.1451 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 4.6238 0.1424 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 4.6153 0.1424 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 4.5701 0.1460 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 4.6410 0.1482 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 4.6502 0.1481 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 4.6529 0.1459 sec/batch
# Nearest to over: antenna, avatar, heavy, kill, donna, abdal, thousand, tocantins,
# Nearest to this: mehmed, fights, manifestations, it, mohenjo, mediocrity, grassy, which,
# Nearest to s: samuel, rioters, vp, worthington, highlights, abstractly, lent, birthday,
# Nearest to with: frequencies, residential, emmer, wheat, what, marker, saw, adults,
# Nearest to first: super, bratislava, supplemental, flavorings, tycoon, flamenco, mogul, medusa,
# Nearest to zero: edition, october, alison, camden, est, ft, trey, valleys,
# Nearest to their: began, palatable, amstrad, piggy, personality, having, do, provide,
# Nearest to may: representable, hoax, phrasing, fragrance, ashton, case, hani, vehicles,
# Nearest to recorded: vcs, star, qualifications, studied, unattended, tryin, nomination, doubleheader,
# Nearest to award: best, fern, intruders, academy, unwelcome, mad, eve, bal,
# Nearest to paris: aerial, devon, crowned, workmen, muzio, ticketing, replay, vinge,
# Nearest to pope: talib, vienna, cripps, squandered, kabbalah, despatch, amadeus, federation,
# Nearest to engineering: cellphones, kum, admittedly, compositional, mujibur, defintion, espionage, recognizing,
# Nearest to shown: subsidence, zapata, bartenders, pasha, damn, isshu, hailstorm, hypoxic,
# Nearest to pressure: policy, scratching, metabolism, tugs, regimen, conveniently, ecclestone, pure,
# Nearest to institute: gamemaster, kyd, hopkins, institutions, ineffectiveness, cartwright, moreno, canterbury,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 4.6545 0.1462 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 4.6417 0.1483 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 4.5894 0.1498 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 4.6220 0.1572 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 4.6649 0.1497 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 4.6174 0.1458 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 4.6333 0.1426 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 4.6430 0.1403 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 4.6010 0.1423 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 4.6273 0.1410 sec/batch
# Nearest to over: antenna, avatar, thousand, abdal, kill, donna, stun, accretion,
# Nearest to this: mehmed, fights, it, mohenjo, manifestations, which, mediocrity, given,
# Nearest to s: samuel, vp, rioters, worthington, abstractly, highlights, comecon, lent,
# Nearest to with: frequencies, residential, emmer, wheat, saws, adults, prompting, saw,
# Nearest to first: super, bratislava, camden, flamenco, nomination, usurper, concave, mogul,
# Nearest to zero: edition, october, alison, camden, ft, chun, trey, ethicists,
# Nearest to their: palatable, do, began, amstrad, piggy, aramaean, provide, continue,
# Nearest to may: representable, phrasing, hoax, fragrance, ashton, case, sufferers, debasing,
# Nearest to recorded: star, vcs, tryin, qualifications, unattended, studied, apology, ola,
# Nearest to award: best, fern, intruders, unwelcome, academy, mad, eve, spamalot,
# Nearest to paris: devon, cot, aerial, crowned, workmen, billionaire, muzio, ticketing,
# Nearest to pope: talib, vienna, cripps, chancellor, squandered, despatch, amadeus, dray,
# Nearest to engineering: cellphones, kum, compositional, mujibur, defintion, admittedly, espionage, kano,
# Nearest to shown: zapata, subsidence, bartenders, pasha, hailstorm, isshu, damn, hypoxic,
# Nearest to pressure: policy, scratching, metabolism, tugs, ecclestone, pure, regimen, convocation,
# Nearest to institute: gamemaster, kyd, institutions, hopkins, cartwright, moreno, belgica, ineffectiveness,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 4.5894 0.1403 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 4.5098 0.1411 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 4.5777 0.1420 sec/batch
# Epoch 1/10 Iteration: 8400 Avg. Training loss: 4.5809 0.1415 sec/batch
# Epoch 1/10 Iteration: 8500 Avg. Training loss: 4.5557 0.1390 sec/batch
# Epoch 1/10 Iteration: 8600 Avg. Training loss: 4.5595 0.1498 sec/batch
# Epoch 1/10 Iteration: 8700 Avg. Training loss: 4.6090 0.1366 sec/batch
# Epoch 1/10 Iteration: 8800 Avg. Training loss: 4.4323 0.1359 sec/batch
# Epoch 1/10 Iteration: 8900 Avg. Training loss: 4.4601 0.1356 sec/batch
# Epoch 1/10 Iteration: 9000 Avg. Training loss: 4.4321 0.1357 sec/batch
# Nearest to over: abdal, antenna, stun, donna, accretion, thousand, avatar, tocantins,
# Nearest to this: fights, mehmed, it, manifestations, mariette, mediocrity, mohenjo, which,
# Nearest to s: samuel, rioters, vp, worthington, longwood, arcadius, neuroscientists, crichton,
# Nearest to with: frequencies, residential, saw, saudis, fsm, emmer, mismanaged, aussie,
# Nearest to first: super, nomination, bratislava, mogul, usurper, joining, camden, concave,
# Nearest to zero: october, edition, three, alison, ft, mcgraw, auguste, trey,
# Nearest to their: palatable, began, amstrad, dudayev, do, aramaean, genevieve, crumpled,
# Nearest to may: ashton, representable, hoax, phrasing, fragrance, case, appleby, debasing,
# Nearest to recorded: star, vcs, ola, tryin, unattended, apology, studied, societas,
# Nearest to award: best, academy, fern, mad, intruders, awards, spamalot, unwelcome,
# Nearest to paris: aerial, crowned, devon, cot, billionaire, workmen, muzio, replay,
# Nearest to pope: talib, vienna, chancellor, cripps, amadeus, dray, despatch, squandered,
# Nearest to engineering: cellphones, kum, espionage, mujibur, defintion, normalize, admittedly, kano,
# Nearest to shown: zapata, hailstorm, bartenders, pasha, subsidence, isshu, damn, hypoxic,
# Nearest to pressure: policy, scratching, tugs, metabolism, physiologic, regimen, ecclestone, convocation,
# Nearest to institute: gamemaster, hopkins, institutions, kyd, belgica, ineffectiveness, cartwright, moreno,
# Epoch 1/10 Iteration: 9100 Avg. Training loss: 4.4929 0.1363 sec/batch
# Epoch 1/10 Iteration: 9200 Avg. Training loss: 4.5716 0.1357 sec/batch
# Epoch 1/10 Iteration: 9300 Avg. Training loss: 4.5918 0.1356 sec/batch
# Epoch 1/10 Iteration: 9400 Avg. Training loss: 4.5641 0.1352 sec/batch
# Epoch 1/10 Iteration: 9500 Avg. Training loss: 4.6452 0.1354 sec/batch
# Epoch 1/10 Iteration: 9600 Avg. Training loss: 4.6467 0.1353 sec/batch
# Epoch 1/10 Iteration: 9700 Avg. Training loss: 4.6054 0.1356 sec/batch
# Epoch 1/10 Iteration: 9800 Avg. Training loss: 4.5499 0.1359 sec/batch
# Epoch 1/10 Iteration: 9900 Avg. Training loss: 4.4429 0.1357 sec/batch
# Epoch 1/10 Iteration: 10000 Avg. Training loss: 4.5600 0.1355 sec/batch
# Nearest to over: antenna, abdal, avatar, stun, donna, thousand, eretria, accretion,
# Nearest to this: it, fights, mohenjo, manifestations, which, mehmed, mariette, grassy,
# Nearest to s: samuel, rioters, vp, neuroscientists, longwood, abstractly, crichton, comecon,
# Nearest to with: frequencies, saudis, residential, reformatory, pytheas, emmer, wheat, saws,
# Nearest to first: super, bratislava, nomination, usurper, flamenco, miramax, concave, joining,
# Nearest to zero: chun, edition, ft, alison, million, est, ethicists, october,
# Nearest to their: palatable, amstrad, began, do, genevieve, dudayev, aramaean, provide,
# Nearest to may: representable, hoax, case, ashton, phrasing, clockrate, appleby, sufferers,
# Nearest to recorded: star, vcs, ola, tryin, societas, detain, studied, unattended,
# Nearest to award: best, academy, awards, fern, spamalot, mad, intruders, unwelcome,
# Nearest to paris: aerial, cot, devon, billionaire, muzio, crowned, replay, glad,
# Nearest to pope: talib, cripps, dray, chancellor, despatch, amadeus, vienna, squandered,
# Nearest to engineering: cellphones, normalize, kum, espionage, mujibur, kano, defintion, compositional,
# Nearest to shown: zapata, hailstorm, subsidence, bartenders, pasha, hypoxic, damn, bose,
# Nearest to pressure: policy, tugs, scratching, metabolism, physiologic, regimen, ecclestone, air,
# Nearest to institute: institutions, gamemaster, kyd, hopkins, cartwright, ineffectiveness, belgica, auxin,
# Epoch 1/10 Iteration: 10100 Avg. Training loss: 4.5604 0.1372 sec/batch
# Epoch 1/10 Iteration: 10200 Avg. Training loss: 4.5939 0.1357 sec/batch
# Epoch 1/10 Iteration: 10300 Avg. Training loss: 4.5475 0.1358 sec/batch
# Epoch 1/10 Iteration: 10400 Avg. Training loss: 4.5830 0.1361 sec/batch
# Epoch 1/10 Iteration: 10500 Avg. Training loss: 4.5739 0.1360 sec/batch
# Epoch 1/10 Iteration: 10600 Avg. Training loss: 4.4644 0.1358 sec/batch
# Epoch 1/10 Iteration: 10700 Avg. Training loss: 4.4062 0.1359 sec/batch
# Epoch 1/10 Iteration: 10800 Avg. Training loss: 4.5533 0.1359 sec/batch
# Epoch 1/10 Iteration: 10900 Avg. Training loss: 4.4855 0.1361 sec/batch
# Epoch 1/10 Iteration: 11000 Avg. Training loss: 4.4927 0.1362 sec/batch
# Nearest to over: antenna, thousand, stun, abdal, eretria, avatar, steadily, donna,
# Nearest to this: it, fights, which, mohenjo, mariette, manifestations, mehmed, mediocrity,
# Nearest to s: samuel, vp, rioters, neuroscientists, abstractly, crichton, longwood, tabloids,
# Nearest to with: frequencies, reformatory, postdoctoral, pytheas, moslem, stamens, adults, saudis,
# Nearest to first: super, bratislava, flamenco, concave, joining, mogul, nomination, the,
# Nearest to zero: alison, edition, ft, october, three, chun, males, ethicists,
# Nearest to their: palatable, amstrad, do, dudayev, began, provide, crumpled, genevieve,
# Nearest to may: representable, hoax, ashton, july, clockrate, appleby, hikers, fragrance,
# Nearest to recorded: star, vcs, tryin, societas, detain, ola, apology, blockbuster,
# Nearest to award: best, academy, awards, mad, spamalot, fern, unwelcome, hayim,
# Nearest to paris: devon, cot, aerial, crowned, billionaire, muzio, ticketing, spaceballs,
# Nearest to pope: talib, cripps, chancellor, amadeus, dray, despatch, ambrose, jozef,
# Nearest to engineering: cellphones, normalize, espionage, kano, defintion, admittedly, javascript, mujibur,
# Nearest to shown: bartenders, hailstorm, zapata, subsidence, damn, pasha, hypoxic, isshu,
# Nearest to pressure: policy, tugs, metabolism, scratching, physiologic, convocation, regimen, beams,
# Nearest to institute: institutions, gamemaster, kyd, hopkins, ineffectiveness, belgica, cartwright, logie,
# Epoch 1/10 Iteration: 11100 Avg. Training loss: 4.5466 0.1365 sec/batch
# Epoch 1/10 Iteration: 11200 Avg. Training loss: 4.5366 0.1356 sec/batch
# Epoch 1/10 Iteration: 11300 Avg. Training loss: 4.5143 0.1353 sec/batch
# Epoch 1/10 Iteration: 11400 Avg. Training loss: 4.5125 0.1356 sec/batch
# Epoch 1/10 Iteration: 11500 Avg. Training loss: 4.5429 0.1357 sec/batch
# Epoch 1/10 Iteration: 11600 Avg. Training loss: 4.5836 0.1353 sec/batch
# Epoch 2/10 Iteration: 11700 Avg. Training loss: 4.5441 0.0563 sec/batch
# Epoch 2/10 Iteration: 11800 Avg. Training loss: 4.5235 0.1355 sec/batch
# Epoch 2/10 Iteration: 11900 Avg. Training loss: 4.4755 0.1357 sec/batch
# Epoch 2/10 Iteration: 12000 Avg. Training loss: 4.5122 0.1356 sec/batch
# Nearest to over: antenna, thousand, abdal, stun, eretria, donna, gagnon, accretion,
# Nearest to this: it, which, fights, mariette, mohenjo, mediocrity, manifestations, mehmed,
# Nearest to s: samuel, vp, neuroscientists, rioters, tabloids, abstractly, crichton, longwood,
# Nearest to with: frequencies, reformatory, postdoctoral, stamens, pytheas, adults, moslem, protester,
# Nearest to first: super, bratislava, mogul, flamenco, the, miramax, joining, nomination,
# Nearest to zero: edition, chun, alison, october, ft, ethicists, carcassonne, amd,
# Nearest to their: do, plastids, palatable, amstrad, dudayev, began, provide, genevieve,
# Nearest to may: representable, hikers, clockrate, hoax, difficulties, sufferers, letterboxes, case,
# Nearest to recorded: star, vcs, tryin, ola, societas, detain, blockbuster, apology,
# Nearest to award: best, academy, awards, spamalot, mad, hayim, medal, fern,
# Nearest to paris: cot, devon, muzio, aerial, ticketing, replay, billionaire, crowned,
# Nearest to pope: talib, cripps, chancellor, amadeus, dray, despatch, ambrose, squandered,
# Nearest to engineering: cellphones, normalize, defintion, espionage, kano, mujibur, admittedly, hypoglycemia,
# Nearest to shown: bartenders, zapata, hailstorm, damn, subsidence, bose, metazoa, pasha,
# Nearest to pressure: policy, tugs, scratching, metabolism, physiologic, convocation, regimen, hospitalization,
# Nearest to institute: institutions, gamemaster, kyd, hopkins, belgica, logie, cartwright, underpinnings,
# Epoch 2/10 Iteration: 12100 Avg. Training loss: 4.4555 0.1367 sec/batch
# Epoch 2/10 Iteration: 12200 Avg. Training loss: 4.4738 0.1360 sec/batch
# Epoch 2/10 Iteration: 12300 Avg. Training loss: 4.4698 0.1360 sec/batch
# Epoch 2/10 Iteration: 12400 Avg. Training loss: 4.4287 0.1361 sec/batch
# Epoch 2/10 Iteration: 12500 Avg. Training loss: 4.4603 0.1355 sec/batch
# Epoch 2/10 Iteration: 12600 Avg. Training loss: 4.4861 0.1358 sec/batch
# Epoch 2/10 Iteration: 12700 Avg. Training loss: 4.4858 0.1356 sec/batch
# Epoch 2/10 Iteration: 12800 Avg. Training loss: 4.4847 0.1357 sec/batch
# Epoch 2/10 Iteration: 12900 Avg. Training loss: 4.5050 0.1359 sec/batch
# Epoch 2/10 Iteration: 13000 Avg. Training loss: 4.4978 0.1358 sec/batch
# Nearest to over: antenna, abdal, thousand, stun, gagnon, donna, eretria, avatar,
# Nearest to this: it, which, fights, another, mohenjo, manifestations, metamorphosis, mediocrity,
# Nearest to s: samuel, vp, neuroscientists, rioters, crichton, abstractly, comecon, tabloids,
# Nearest to with: frequencies, pytheas, stamens, reformatory, postdoctoral, moslem, saws, ata,
# Nearest to first: super, flamenco, mogul, the, miramax, caterina, naca, concave,
# Nearest to zero: alison, chun, edition, october, amd, ethicists, trey, mega,
# Nearest to their: do, plastids, provide, them, palatable, aramaean, dudayev, amstrad,
# Nearest to may: clockrate, sufferers, representable, hoax, difficulties, hikers, july, phrasing,
# Nearest to recorded: star, vcs, tryin, societas, ola, apology, blockbuster, detain,
# Nearest to award: best, awards, academy, hayim, spamalot, mad, bacchae, medal,
# Nearest to paris: devon, cot, nantes, muzio, freeland, billionaire, crowned, spaceballs,
# Nearest to pope: talib, cripps, chancellor, dray, amadeus, ambrose, despatch, squandered,
# Nearest to engineering: cellphones, normalize, defintion, electrical, espionage, kano, electric, admittedly,
# Nearest to shown: bartenders, hailstorm, damn, subsidence, zapata, hypoxic, headingley, metazoa,
# Nearest to pressure: policy, metabolism, tugs, blood, physiologic, scratching, regimen, beams,
# Nearest to institute: institutions, gamemaster, hopkins, kyd, underpinnings, belgica, logie, ambience,
# Epoch 2/10 Iteration: 13100 Avg. Training loss: 4.4915 0.1375 sec/batch
# Epoch 2/10 Iteration: 13200 Avg. Training loss: 4.4833 0.1355 sec/batch
# Epoch 2/10 Iteration: 13300 Avg. Training loss: 4.4922 0.1355 sec/batch
# Epoch 2/10 Iteration: 13400 Avg. Training loss: 4.3603 0.1355 sec/batch
# Epoch 2/10 Iteration: 13500 Avg. Training loss: 4.5043 0.1356 sec/batch
# Epoch 2/10 Iteration: 13600 Avg. Training loss: 4.5287 0.1355 sec/batch
# Epoch 2/10 Iteration: 13700 Avg. Training loss: 4.4880 0.1357 sec/batch
# Epoch 2/10 Iteration: 13800 Avg. Training loss: 4.4966 0.1355 sec/batch
# Epoch 2/10 Iteration: 13900 Avg. Training loss: 4.4992 0.1357 sec/batch
# Epoch 2/10 Iteration: 14000 Avg. Training loss: 4.5014 0.1357 sec/batch
# Nearest to over: antenna, stun, thousand, abdal, gagnon, donna, cogs, eretria,
# Nearest to this: it, which, fights, mariette, mohenjo, another, metamorphosis, manifestations,
# Nearest to s: samuel, neuroscientists, crichton, tabloids, vp, rages, buell, rioters,
# Nearest to with: frequencies, reformatory, pytheas, moslem, stamens, postdoctoral, galore, adults,
# Nearest to first: super, the, flamenco, mogul, miramax, bratislava, tycoon, caterina,
# Nearest to zero: edition, october, chun, alison, february, approximately, extolling, trey,
# Nearest to their: plastids, them, do, palatable, dudayev, genevieve, amstrad, began,
# Nearest to may: hikers, can, hoax, sufferers, representable, clockrate, ashton, difficulties,
# Nearest to recorded: star, vcs, tryin, ola, societas, detain, blockbuster, apology,
# Nearest to award: best, awards, academy, hayim, spamalot, mad, planer, bacchae,
# Nearest to paris: cot, nantes, muzio, devon, billionaire, freeland, spaceballs, glad,
# Nearest to pope: talib, cripps, chancellor, amadeus, dray, ambrose, jozef, squandered,
# Nearest to engineering: cellphones, normalize, espionage, defintion, kano, electrical, mujibur, hypoglycemia,
# Nearest to shown: hailstorm, bartenders, zapata, subsidence, damn, hypoxic, bose, headingley,
# Nearest to pressure: policy, metabolism, blood, tugs, physiologic, beams, regimen, scratching,
# Nearest to institute: institutions, gamemaster, hopkins, kyd, underpinnings, belgica, ambience, provides,
# Epoch 2/10 Iteration: 14100 Avg. Training loss: 4.4900 0.1371 sec/batch
# Epoch 2/10 Iteration: 14200 Avg. Training loss: 4.4838 0.1354 sec/batch
# Epoch 2/10 Iteration: 14300 Avg. Training loss: 4.4550 0.1357 sec/batch
# Epoch 2/10 Iteration: 14400 Avg. Training loss: 4.4365 0.1360 sec/batch
# Epoch 2/10 Iteration: 14500 Avg. Training loss: 4.3484 0.1359 sec/batch
# Epoch 2/10 Iteration: 14600 Avg. Training loss: 4.3869 0.1359 sec/batch
# Epoch 2/10 Iteration: 14700 Avg. Training loss: 4.4888 0.1362 sec/batch
# Epoch 2/10 Iteration: 14800 Avg. Training loss: 4.4258 0.1365 sec/batch
# Epoch 2/10 Iteration: 14900 Avg. Training loss: 4.4512 0.1360 sec/batch
# Epoch 2/10 Iteration: 15000 Avg. Training loss: 4.4519 0.1359 sec/batch
# Nearest to over: thousand, antenna, stun, abdal, eretria, gagnon, cogs, donna,
# Nearest to this: it, which, another, mariette, a, mohenjo, fights, given,
# Nearest to s: samuel, neuroscientists, crichton, comecon, rioters, vp, longwood, rages,
# Nearest to with: frequencies, moslem, stamens, pytheas, reformatory, between, emmer, galore,
# Nearest to first: the, flamenco, super, bratislava, miramax, mogul, caterina, usurper,
# Nearest to zero: chun, edition, october, three, extolling, ethicists, males, approximately,
# Nearest to their: do, plastids, them, amstrad, continue, provide, palatable, herding,
# Nearest to may: can, letterboxes, clockrate, hikers, hoax, would, sufferers, representable,
# Nearest to recorded: star, vcs, tryin, detain, societas, ola, apology, quill,
# Nearest to award: best, awards, academy, medal, hayim, mad, spamalot, bacchae,
# Nearest to paris: nantes, cot, devon, billionaire, muzio, freeland, workmen, spaceballs,
# Nearest to pope: talib, cripps, amadeus, chancellor, dray, ambrose, squandered, jozef,
# Nearest to engineering: cellphones, normalize, espionage, electrical, defintion, electric, kano, princeton,
# Nearest to shown: hailstorm, bartenders, hypoxic, damn, zapata, subsidence, headingley, bose,
# Nearest to pressure: policy, metabolism, blood, tugs, physiologic, scratching, beams, regimen,
# Nearest to institute: institutions, hopkins, gamemaster, underpinnings, kyd, research, provides, belgica,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 4.4584 0.1370 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 4.4009 0.1356 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 4.4739 0.1355 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 4.4778 0.1361 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 4.4598 0.1357 sec/batch
# Epoch 2/10 Iteration: 15600 Avg. Training loss: 4.4478 0.1355 sec/batch
# Epoch 2/10 Iteration: 15700 Avg. Training loss: 4.4481 0.1354 sec/batch
# Epoch 2/10 Iteration: 15800 Avg. Training loss: 4.5000 0.1354 sec/batch
# Epoch 2/10 Iteration: 15900 Avg. Training loss: 4.4879 0.1355 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 4.4231 0.1359 sec/batch
# Nearest to over: thousand, antenna, gagnon, abdal, cogs, stun, eretria, avatar,
# Nearest to this: it, which, another, mohenjo, mariette, fights, a, wording,
# Nearest to s: samuel, neuroscientists, crichton, vp, rioters, tabloids, longwood, buell,
# Nearest to with: frequencies, pytheas, moslem, stamens, emmer, reformatory, galore, postdoctoral,
# Nearest to first: super, the, flamenco, caterina, miramax, mogul, bratislava, remaking,
# Nearest to zero: edition, october, three, chun, one, alison, six, ethicists,
# Nearest to their: plastids, them, do, amstrad, genevieve, continue, labels, herding,
# Nearest to may: can, letterboxes, hikers, clockrate, would, july, might, sufferers,
# Nearest to recorded: vcs, detain, star, tryin, ola, societas, quill, apology,
# Nearest to award: awards, best, academy, medal, spamalot, mad, bacchae, hayim,
# Nearest to paris: nantes, billionaire, devon, muzio, duc, cot, freeland, glad,
# Nearest to pope: talib, cripps, amadeus, chancellor, dray, squandered, jozef, despatch,
# Nearest to engineering: cellphones, normalize, espionage, kano, princeton, electric, mujibur, defintion,
# Nearest to shown: hypoxic, damn, hailstorm, zapata, bartenders, subsidence, headingley, bose,
# Nearest to pressure: policy, metabolism, blood, tugs, beams, physiologic, temperature, banias,
# Nearest to institute: institutions, hopkins, gamemaster, kyd, underpinnings, cartwright, logie, delhi,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 4.4512 0.1374 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 4.4284 0.1359 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 4.4719 0.1359 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 4.4969 0.1359 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 4.4665 0.1361 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 4.4988 0.1359 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 4.4278 0.1360 sec/batch
# Epoch 2/10 Iteration: 16800 Avg. Training loss: 4.3955 0.1362 sec/batch
# Epoch 2/10 Iteration: 16900 Avg. Training loss: 4.4038 0.1357 sec/batch
# Epoch 2/10 Iteration: 17000 Avg. Training loss: 4.4581 0.1357 sec/batch
# Nearest to over: thousand, antenna, gagnon, cogs, eretria, stun, within, donna,
# Nearest to this: it, which, another, fights, mariette, a, mohenjo, fact,
# Nearest to s: samuel, neuroscientists, crichton, vp, tabloids, rioters, longwood, comecon,
# Nearest to with: frequencies, moslem, pytheas, stamens, between, discipline, emmer, galore,
# Nearest to first: flamenco, the, miramax, caterina, mogul, nomination, supplemental, remaking,
# Nearest to zero: october, edition, chun, three, alison, approximately, campana, extolling,
# Nearest to their: plastids, do, them, continue, amstrad, provide, genevieve, herding,
# Nearest to may: can, letterboxes, would, hikers, clockrate, sufferers, might, july,
# Nearest to recorded: vcs, detain, ola, tryin, quill, star, societas, apology,
# Nearest to award: awards, best, academy, medal, spamalot, bacchae, mad, hayim,
# Nearest to paris: nantes, billionaire, devon, cot, muzio, freeland, duc, glad,
# Nearest to pope: talib, cripps, amadeus, chancellor, jozef, dray, electrophoretic, despatch,
# Nearest to engineering: cellphones, normalize, electrical, espionage, kano, electric, engineers, energetics,
# Nearest to shown: damn, hypoxic, bartenders, zapata, hailstorm, yttrium, subsidence, headingley,
# Nearest to pressure: policy, metabolism, blood, tugs, temperature, physiologic, hospitalization, heat,
# Nearest to institute: institutions, hopkins, gamemaster, kyd, underpinnings, provides, delhi, belgica,
# Epoch 2/10 Iteration: 17100 Avg. Training loss: 4.4303 0.1370 sec/batch
# Epoch 2/10 Iteration: 17200 Avg. Training loss: 4.4445 0.1358 sec/batch
# Epoch 2/10 Iteration: 17300 Avg. Training loss: 4.4702 0.1360 sec/batch
# Epoch 2/10 Iteration: 17400 Avg. Training loss: 4.4545 0.1358 sec/batch
# Epoch 2/10 Iteration: 17500 Avg. Training loss: 4.3840 0.1362 sec/batch
# Epoch 2/10 Iteration: 17600 Avg. Training loss: 4.4662 0.1354 sec/batch
# Epoch 2/10 Iteration: 17700 Avg. Training loss: 4.4121 0.1354 sec/batch
# Epoch 2/10 Iteration: 17800 Avg. Training loss: 4.4621 0.1355 sec/batch
# Epoch 2/10 Iteration: 17900 Avg. Training loss: 4.3571 0.1352 sec/batch
# Epoch 2/10 Iteration: 18000 Avg. Training loss: 4.4462 0.1355 sec/batch
# Nearest to over: gagnon, thousand, antenna, cogs, eretria, stun, servicemen, within,
# Nearest to this: it, another, which, fights, a, mariette, fact, mediocrity,
# Nearest to s: samuel, crichton, neuroscientists, tabloids, rioters, taylor, longwood, abstractly,
# Nearest to with: frequencies, emmer, between, pytheas, galore, discipline, moslem, stamens,
# Nearest to first: the, caterina, mogul, flamenco, nomination, tycoon, miramax, identifies,
# Nearest to zero: edition, october, chun, three, one, amd, alison, approximately,
# Nearest to their: them, plastids, do, amstrad, continue, provide, labels, genevieve,
# Nearest to may: can, would, letterboxes, hikers, might, sufferers, clockrate, hoax,
# Nearest to recorded: tryin, vcs, ola, societas, detain, quill, star, blockbuster,
# Nearest to award: best, awards, academy, medal, bacchae, spamalot, hayim, mad,
# Nearest to paris: nantes, ephrem, muzio, devon, billionaire, duc, cot, aerial,
# Nearest to pope: talib, cripps, chancellor, jozef, dray, amadeus, electrophoretic, despatch,
# Nearest to engineering: cellphones, normalize, electrical, kano, espionage, engineers, energetics, electric,
# Nearest to shown: damn, bartenders, hailstorm, hypoxic, zapata, subsidence, headingley, yttrium,
# Nearest to pressure: policy, blood, metabolism, tugs, temperature, physiologic, hospitalization, banias,
# Nearest to institute: institutions, hopkins, kyd, gamemaster, underpinnings, provides, cartwright, logie,
# Epoch 2/10 Iteration: 18100 Avg. Training loss: 4.4780 0.1373 sec/batch
# Epoch 2/10 Iteration: 18200 Avg. Training loss: 4.4227 0.1361 sec/batch
# Epoch 2/10 Iteration: 18300 Avg. Training loss: 4.3025 0.1353 sec/batch
# Epoch 2/10 Iteration: 18400 Avg. Training loss: 4.4604 0.1360 sec/batch
# Epoch 2/10 Iteration: 18500 Avg. Training loss: 4.4592 0.1359 sec/batch
# Epoch 2/10 Iteration: 18600 Avg. Training loss: 4.4468 0.1360 sec/batch
# Epoch 2/10 Iteration: 18700 Avg. Training loss: 4.4384 0.1358 sec/batch
# Epoch 2/10 Iteration: 18800 Avg. Training loss: 4.5057 0.1361 sec/batch
# Epoch 2/10 Iteration: 18900 Avg. Training loss: 4.4314 0.1362 sec/batch
# Epoch 2/10 Iteration: 19000 Avg. Training loss: 4.3823 0.1360 sec/batch
# Nearest to over: thousand, eretria, within, abdal, gagnon, stun, spouses, antenna,
# Nearest to this: it, another, which, mariette, fights, mohenjo, a, wording,
# Nearest to s: samuel, rioters, comecon, crichton, longwood, abstractly, neuroscientists, amasis,
# Nearest to with: pytheas, frequencies, between, emmer, discipline, stamens, moslem, galore,
# Nearest to first: the, flamenco, miramax, caterina, mogul, nomination, bratislava, identifies,
# Nearest to zero: october, chun, three, edition, approximately, the, six, one,
# Nearest to their: plastids, them, do, amstrad, continue, viii, genevieve, herding,
# Nearest to may: can, letterboxes, would, hikers, hoax, clockrate, might, sufferers,
# Nearest to recorded: detain, vcs, societas, tryin, ola, quill, star, blockbuster,
# Nearest to award: best, awards, academy, medal, spamalot, bacchae, awarded, hayim,
# Nearest to paris: nantes, billionaire, ephrem, muzio, freeland, duc, devon, arctan,
# Nearest to pope: talib, cripps, jozef, dray, electrophoretic, despatch, chancellor, squandered,
# Nearest to engineering: cellphones, normalize, kano, electrical, espionage, electric, hypoglycemia, energetics,
# Nearest to shown: damn, hypoxic, hailstorm, bartenders, zapata, headingley, subsidence, pasha,
# Nearest to pressure: policy, blood, tugs, metabolism, temperature, banias, glissando, heat,
# Nearest to institute: institutions, hopkins, kyd, gamemaster, underpinnings, provides, logie, cartwright,
# Epoch 2/10 Iteration: 19100 Avg. Training loss: 4.4933 0.1369 sec/batch
# Epoch 2/10 Iteration: 19200 Avg. Training loss: 4.4678 0.1354 sec/batch
# Epoch 2/10 Iteration: 19300 Avg. Training loss: 4.4311 0.1357 sec/batch
# Epoch 2/10 Iteration: 19400 Avg. Training loss: 4.4504 0.1359 sec/batch
# Epoch 2/10 Iteration: 19500 Avg. Training loss: 4.4665 0.1356 sec/batch
# Epoch 2/10 Iteration: 19600 Avg. Training loss: 4.4670 0.1357 sec/batch
# Epoch 2/10 Iteration: 19700 Avg. Training loss: 4.4579 0.1355 sec/batch
# Epoch 2/10 Iteration: 19800 Avg. Training loss: 4.3687 0.1355 sec/batch
# Epoch 2/10 Iteration: 19900 Avg. Training loss: 4.3731 0.1356 sec/batch
# Epoch 2/10 Iteration: 20000 Avg. Training loss: 4.3920 0.1358 sec/batch
# Nearest to over: thousand, eretria, abdal, stun, spouses, within, antenna, cogs,
# Nearest to this: it, which, another, a, mohenjo, mariette, fact, wording,
# Nearest to s: samuel, comecon, abstractly, neuroscientists, rioters, its, crichton, tabloids,
# Nearest to with: frequencies, between, pytheas, emmer, stamens, moslem, discipline, homogeneous,
# Nearest to first: miramax, flamenco, caterina, mogul, the, vanier, second, tycoon,
# Nearest to zero: three, october, chun, edition, one, six, approximately, the,
# Nearest to their: them, plastids, do, continue, amstrad, own, provide, they,
# Nearest to may: can, would, letterboxes, or, might, hikers, hoax, sufferers,
# Nearest to recorded: societas, detain, vcs, tryin, quill, ola, star, since,
# Nearest to award: awards, best, academy, medal, spamalot, bacchae, hayim, planer,
# Nearest to paris: nantes, muzio, ephrem, billionaire, freeland, duc, cot, devon,
# Nearest to pope: talib, cripps, dray, jozef, electrophoretic, squandered, chancellor, ambrose,
# Nearest to engineering: cellphones, normalize, electrical, kano, espionage, electric, princeton, engineers,
# Nearest to shown: hailstorm, damn, zapata, hypoxic, bartenders, headingley, henryk, pasha,
# Nearest to pressure: policy, blood, tugs, metabolism, banias, temperature, regimen, hospitalization,
# Nearest to institute: institutions, hopkins, kyd, gamemaster, underpinnings, provides, cartwright, belgica,
# Epoch 2/10 Iteration: 20100 Avg. Training loss: 4.4162 0.1375 sec/batch
# Epoch 2/10 Iteration: 20200 Avg. Training loss: 4.4039 0.1360 sec/batch
# Epoch 2/10 Iteration: 20300 Avg. Training loss: 4.3913 0.1362 sec/batch
# Epoch 2/10 Iteration: 20400 Avg. Training loss: 4.4297 0.1364 sec/batch
# Epoch 2/10 Iteration: 20500 Avg. Training loss: 4.1534 0.1360 sec/batch
# Epoch 2/10 Iteration: 20600 Avg. Training loss: 4.3487 0.1360 sec/batch
# Epoch 2/10 Iteration: 20700 Avg. Training loss: 4.3095 0.1362 sec/batch
# Epoch 2/10 Iteration: 20800 Avg. Training loss: 4.4084 0.1361 sec/batch
# Epoch 2/10 Iteration: 20900 Avg. Training loss: 4.4391 0.1361 sec/batch
# Epoch 2/10 Iteration: 21000 Avg. Training loss: 4.4478 0.1360 sec/batch
# Nearest to over: thousand, abdal, eretria, donna, cogs, stun, spouses, gagnon,
# Nearest to this: it, which, another, mariette, a, fights, woolsack, wording,
# Nearest to s: samuel, crichton, neuroscientists, tabloids, rioters, comecon, longwood, its,
# Nearest to with: between, frequencies, pytheas, discipline, moslem, galore, exemplar, eurystheus,
# Nearest to first: the, nomination, flamenco, miramax, caterina, second, mogul, heiress,
# Nearest to zero: chun, edition, three, october, million, ethicists, february, barrels,
# Nearest to their: them, plastids, do, own, genevieve, continue, they, amstrad,
# Nearest to may: would, can, letterboxes, july, might, hoax, appleby, clockrate,
# Nearest to recorded: detain, quill, ola, societas, tryin, vcs, star, blockbuster,
# Nearest to award: awards, best, academy, medal, spamalot, hayim, planer, bacchae,
# Nearest to paris: nantes, ephrem, muzio, billionaire, freeland, duc, cot, devon,
# Nearest to pope: talib, cripps, dray, jozef, unraveling, bishops, viii, ambrose,
# Nearest to engineering: cellphones, normalize, electrical, electric, espionage, kano, princeton, engineers,
# Nearest to shown: hailstorm, damn, henryk, hypoxic, zapata, pasha, bartenders, isshu,
# Nearest to pressure: policy, tugs, blood, metabolism, banias, temperature, hospitalization, regimen,
# Nearest to institute: hopkins, institutions, gamemaster, kyd, underpinnings, cartwright, provides, isadore,
# Epoch 2/10 Iteration: 21100 Avg. Training loss: 4.4895 0.1371 sec/batch
# Epoch 2/10 Iteration: 21200 Avg. Training loss: 4.5059 0.1359 sec/batch
# Epoch 2/10 Iteration: 21300 Avg. Training loss: 4.5045 0.1355 sec/batch
# Epoch 2/10 Iteration: 21400 Avg. Training loss: 4.4583 0.1358 sec/batch
# Epoch 2/10 Iteration: 21500 Avg. Training loss: 4.3823 0.1357 sec/batch
# Epoch 2/10 Iteration: 21600 Avg. Training loss: 4.3711 0.1358 sec/batch
# Epoch 2/10 Iteration: 21700 Avg. Training loss: 4.4467 0.1357 sec/batch
# Epoch 2/10 Iteration: 21800 Avg. Training loss: 4.3939 0.1356 sec/batch
# Epoch 2/10 Iteration: 21900 Avg. Training loss: 4.4280 0.1355 sec/batch
# Epoch 2/10 Iteration: 22000 Avg. Training loss: 4.4440 0.1358 sec/batch
# Nearest to over: thousand, stun, eretria, cogs, pixel, antenna, abdal, within,
# Nearest to this: it, another, which, a, mariette, mohenjo, fights, fact,
# Nearest to s: samuel, neuroscientists, tabloids, crichton, rages, taylor, its, vp,
# Nearest to with: between, pytheas, frequencies, stamens, emmer, moslem, discipline, reformatory,
# Nearest to first: the, flamenco, miramax, second, caterina, mogul, nomination, bratislava,
# Nearest to zero: chun, three, edition, campana, approximately, ethicists, barrels, the,
# Nearest to their: them, plastids, do, labels, amstrad, genevieve, own, continue,
# Nearest to may: can, would, letterboxes, might, or, july, hoax, clockrate,
# Nearest to recorded: quill, detain, ola, societas, tryin, vcs, star, zipper,
# Nearest to award: awards, best, academy, medal, spamalot, hayim, planer, bacchae,
# Nearest to paris: nantes, billionaire, ephrem, duc, freeland, muzio, devon, cot,
# Nearest to pope: talib, cripps, dray, jozef, viii, unraveling, bishops, enacts,
# Nearest to engineering: cellphones, electrical, normalize, electric, espionage, engineers, energetics, princeton,
# Nearest to shown: hailstorm, zapata, hypoxic, damn, headingley, bartenders, henryk, isshu,
# Nearest to pressure: policy, tugs, blood, metabolism, banias, regimen, hospitalization, temperature,
# Nearest to institute: institutions, hopkins, underpinnings, gamemaster, kyd, harvard, provides, cartwright,
# Epoch 2/10 Iteration: 22100 Avg. Training loss: 4.4303 0.1375 sec/batch
# Epoch 2/10 Iteration: 22200 Avg. Training loss: 4.4388 0.1362 sec/batch
# Epoch 2/10 Iteration: 22300 Avg. Training loss: 4.2578 0.1361 sec/batch
# Epoch 2/10 Iteration: 22400 Avg. Training loss: 4.2913 0.1360 sec/batch
# Epoch 2/10 Iteration: 22500 Avg. Training loss: 4.4500 0.1364 sec/batch
# Epoch 2/10 Iteration: 22600 Avg. Training loss: 4.2994 0.1359 sec/batch
# Epoch 2/10 Iteration: 22700 Avg. Training loss: 4.4168 0.1359 sec/batch
# ...
# Nearest to paris: nantes, ephrem, freeland, duc, workmen, smelted, billionaire, shoals,
# Nearest to pope: talib, cripps, unraveling, dray, jozef, rhododendron, viii, delius,
# Nearest to engineering: cellphones, electrical, engineers, normalize, espionage, electric, energetics, hypoglycemia,
# Nearest to shown: hailstorm, zapata, hypoxic, damn, headingley, henryk, pasha, shows,
# Nearest to pressure: policy, blood, tugs, temperature, hospitalization, regimen, metabolism, beams,
# Nearest to institute: institutions, underpinnings, hopkins, kyd, gamemaster, provides, harvard, engineering,
# Epoch 3/10 Iteration: 26100 Avg. Training loss: 4.3333 0.1373 sec/batch
# Epoch 3/10 Iteration: 26200 Avg. Training loss: 4.2215 0.1365 sec/batch
# Epoch 3/10 Iteration: 26300 Avg. Training loss: 4.3731 0.1362 sec/batch
# Epoch 3/10 Iteration: 26400 Avg. Training loss: 4.3495 0.1358 sec/batch
# Epoch 3/10 Iteration: 26500 Avg. Training loss: 4.3878 0.1361 sec/batch
# Epoch 3/10 Iteration: 26600 Avg. Training loss: 4.3568 0.1362 sec/batch
# Epoch 3/10 Iteration: 26700 Avg. Training loss: 4.3677 0.1360 sec/batch
# Epoch 3/10 Iteration: 26800 Avg. Training loss: 4.2904 0.1360 sec/batch
# Epoch 3/10 Iteration: 26900 Avg. Training loss: 4.3788 0.1360 sec/batch
# Epoch 3/10 Iteration: 27000 Avg. Training loss: 4.4096 0.1362 sec/batch
# Nearest to over: thousand, pixel, cogs, gagnon, stun, spouses, eretria, federations,
# Nearest to this: it, which, another, a, mariette, fact, wording, mohenjo,
# Nearest to s: samuel, its, crichton, taylor, rages, tabloids, amasis, the,
# Nearest to with: between, pytheas, sleeves, frequencies, moslem, galore, sweaty, prompting,
# Nearest to first: second, the, flamenco, mogul, caterina, miramax, vanier, tycoon,
# Nearest to zero: three, six, one, the, campana, edition, approximately, october,
# Nearest to their: them, they, own, plastids, shahada, do, genevieve, labels,
# Nearest to may: can, would, might, letterboxes, or, july, will, hikers,
# Nearest to recorded: quill, societas, detain, tryin, since, vcs, recognisable, zipper,
# Nearest to award: awards, best, academy, medal, awarded, nominations, achievement, nominated,
# Nearest to paris: nantes, ephrem, freeland, workmen, duc, cielo, shoals, glad,
# Nearest to pope: talib, unraveling, cripps, dray, jozef, rhododendron, squandered, viii,
# Nearest to engineering: cellphones, engineers, electrical, normalize, espionage, institute, seattle, princeton,
# Nearest to shown: hailstorm, hypoxic, zapata, shows, damn, henryk, isshu, headingley,
# Nearest to pressure: policy, blood, temperature, tugs, metabolism, hospitalization, regimen, beams,
# Nearest to institute: institutions, hopkins, underpinnings, kyd, gamemaster, engineering, provides, harvard,
# Epoch 3/10 Iteration: 27100 Avg. Training loss: 4.3999 0.1378 sec/batch
# Epoch 3/10 Iteration: 27200 Avg. Training loss: 4.3693 0.1362 sec/batch
# Epoch 3/10 Iteration: 27300 Avg. Training loss: 4.3866 0.1360 sec/batch
# Epoch 3/10 Iteration: 27400 Avg. Training loss: 4.3747 0.1361 sec/batch
# Epoch 3/10 Iteration: 27500 Avg. Training loss: 4.4333 0.1358 sec/batch
# Epoch 3/10 Iteration: 27600 Avg. Training loss: 4.3168 0.1361 sec/batch
# Epoch 3/10 Iteration: 27700 Avg. Training loss: 4.4123 0.1364 sec/batch
# Epoch 3/10 Iteration: 27800 Avg. Training loss: 4.3401 0.1365 sec/batch
# Epoch 3/10 Iteration: 27900 Avg. Training loss: 4.3876 0.1366 sec/batch
# Epoch 3/10 Iteration: 28000 Avg. Training loss: 4.3930 0.1362 sec/batch
# Nearest to over: pixel, thousand, cogs, gagnon, stun, eretria, within, gaussian,
# Nearest to this: it, another, which, a, fact, mariette, woolsack, that,
# Nearest to s: samuel, its, crichton, taylor, tabloids, rages, the, amasis,
# Nearest to with: between, pytheas, frequencies, ata, sleeves, sweaty, accompanying, moslem,
# Nearest to first: the, second, flamenco, caterina, miramax, mogul, before, vico,
# Nearest to zero: three, one, the, edition, six, campana, approximately, october,
# Nearest to their: them, they, own, genevieve, plastids, do, labels, shahada,
# Nearest to may: can, would, might, letterboxes, or, will, hikers, july,
# Nearest to recorded: quill, detain, societas, tryin, since, vcs, album, recognisable,
# Nearest to award: awards, best, academy, medal, awarded, nominations, achievement, nominated,
# Nearest to paris: nantes, ephrem, duc, freeland, workmen, smelted, curzon, glad,
# Nearest to pope: cripps, talib, dray, jozef, unraveling, rhododendron, enacts, delius,
# Nearest to engineering: cellphones, engineers, normalize, electrical, espionage, seattle, princeton, electric,
# Nearest to shown: hypoxic, shows, zapata, hailstorm, damn, seen, headingley, henryk,
# Nearest to pressure: policy, temperature, blood, metabolism, tugs, hospitalization, beams, heat,
# Nearest to institute: hopkins, institutions, underpinnings, gamemaster, kyd, provides, interdisciplinary, trustees,
# Epoch 3/10 Iteration: 28100 Avg. Training loss: 4.4465 0.1367 sec/batch
# Epoch 3/10 Iteration: 28200 Avg. Training loss: 4.4080 0.1358 sec/batch
# Epoch 3/10 Iteration: 28300 Avg. Training loss: 4.3807 0.1361 sec/batch
# Epoch 3/10 Iteration: 28400 Avg. Training loss: 4.2834 0.1364 sec/batch
# Epoch 3/10 Iteration: 28500 Avg. Training loss: 4.3760 0.1366 sec/batch
# Epoch 3/10 Iteration: 28600 Avg. Training loss: 4.3202 0.1382 sec/batch
# Epoch 3/10 Iteration: 28700 Avg. Training loss: 4.4005 0.1376 sec/batch
# Epoch 3/10 Iteration: 28800 Avg. Training loss: 4.3955 0.1374 sec/batch
# Epoch 3/10 Iteration: 28900 Avg. Training loss: 4.3713 0.1378 sec/batch
# Epoch 3/10 Iteration: 29000 Avg. Training loss: 4.4159 0.1378 sec/batch
# Nearest to over: thousand, pixel, gagnon, cogs, gaussian, within, stun, eretria,
# Nearest to this: it, which, another, a, that, fact, mariette, wording,
# Nearest to s: samuel, its, tabloids, crichton, the, taylor, rages, amasis,
# Nearest to with: between, pytheas, moslem, galore, messengers, emmer, eurystheus, accompanying,
# Nearest to first: the, second, flamenco, caterina, mogul, before, miramax, sergius,
# Nearest to zero: three, approximately, campana, edition, one, october, barrels, six,
# Nearest to their: them, they, own, plastids, do, genevieve, shahada, continue,
# Nearest to may: can, would, might, letterboxes, or, will, spl, must,
# Nearest to recorded: quill, detain, societas, tryin, since, album, recognisable, vcs,
# Nearest to award: awards, best, academy, medal, awarded, nominations, achievement, nominated,
# Nearest to paris: nantes, ephrem, workmen, smelted, freeland, duc, billionaire, glad,
# Nearest to pope: cripps, talib, dray, jozef, unraveling, rhododendron, delius, contained,
# Nearest to engineering: cellphones, engineers, electrical, normalize, espionage, energetics, electric, seattle,
# Nearest to shown: shows, zapata, damn, hypoxic, hailstorm, seen, headingley, henryk,
# Nearest to pressure: policy, temperature, blood, tugs, hospitalization, metabolism, regimen, quantity,
# Nearest to institute: hopkins, underpinnings, institutions, kyd, gamemaster, trustees, interdisciplinary, provides,
# Epoch 3/10 Iteration: 29100 Avg. Training loss: 4.3237 0.1388 sec/batch
# Epoch 3/10 Iteration: 29200 Avg. Training loss: 4.4053 0.1378 sec/batch
# Epoch 3/10 Iteration: 29300 Avg. Training loss: 4.3380 0.1376 sec/batch
# Epoch 3/10 Iteration: 29400 Avg. Training loss: 4.3764 0.1376 sec/batch
# Epoch 3/10 Iteration: 29500 Avg. Training loss: 4.3866 0.1377 sec/batch
# Epoch 3/10 Iteration: 29600 Avg. Training loss: 4.3256 0.1378 sec/batch
# Epoch 3/10 Iteration: 29700 Avg. Training loss: 4.4064 0.1384 sec/batch
# Epoch 3/10 Iteration: 29800 Avg. Training loss: 4.3729 0.1380 sec/batch
# Epoch 3/10 Iteration: 29900 Avg. Training loss: 4.3617 0.1381 sec/batch
# Epoch 3/10 Iteration: 30000 Avg. Training loss: 4.2692 0.1379 sec/batch
# Nearest to over: thousand, eretria, federations, gagnon, cogs, years, several, abdal,
# Nearest to this: it, which, another, a, fact, mariette, that, wording,
# Nearest to s: its, samuel, the, amasis, rages, of, taylor, longwood,
# Nearest to with: between, pytheas, emmer, galore, and, ata, prompting, moslem,
# Nearest to first: second, the, mogul, caterina, before, flamenco, miramax, tycoon,
# Nearest to zero: three, two, one, approximately, six, five, campana, the,
# Nearest to their: them, they, own, plastids, do, shahada, genevieve, amstrad,
# Nearest to may: can, would, might, letterboxes, will, or, could, must,
# Nearest to recorded: quill, detain, societas, tryin, since, recognisable, album, vcs,
# Nearest to award: awards, best, academy, nominations, awarded, medal, achievement, nominated,
# Nearest to paris: nantes, ephrem, smelted, shoals, workmen, glad, freeland, bassoonist,
# Nearest to pope: dray, unraveling, cripps, talib, rhododendron, jozef, contained, enacts,
# Nearest to engineering: cellphones, engineers, electrical, normalize, espionage, energetics, defense, seattle,
# Nearest to shown: shows, henryk, zapata, seen, hypoxic, hailstorm, damn, headingley,
# Nearest to pressure: policy, blood, temperature, hospitalization, tugs, regimen, metabolism, quantity,
# Nearest to institute: hopkins, institutions, underpinnings, kyd, gamemaster, provides, interdisciplinary, rebroadcast,
# Epoch 3/10 Iteration: 30100 Avg. Training loss: 4.3979 0.1395 sec/batch
# Epoch 3/10 Iteration: 30200 Avg. Training loss: 4.4018 0.1384 sec/batch
# Epoch 3/10 Iteration: 30300 Avg. Training loss: 4.3786 0.1381 sec/batch
# Epoch 3/10 Iteration: 30400 Avg. Training loss: 4.4241 0.1392 sec/batch
# Epoch 3/10 Iteration: 30500 Avg. Training loss: 4.4136 0.1387 sec/batch
# Epoch 3/10 Iteration: 30600 Avg. Training loss: 4.3024 0.1387 sec/batch
# Epoch 3/10 Iteration: 30700 Avg. Training loss: 4.3869 0.1387 sec/batch
# Epoch 3/10 Iteration: 30800 Avg. Training loss: 4.4044 0.1387 sec/batch
# Epoch 3/10 Iteration: 30900 Avg. Training loss: 4.4012 0.1384 sec/batch
# Epoch 3/10 Iteration: 31000 Avg. Training loss: 4.3679 0.1386 sec/batch
# Nearest to over: thousand, pixel, cogs, spouses, eretria, federations, several, abdal,
# Nearest to this: it, which, another, a, mariette, fact, woolsack, that,
# Nearest to s: samuel, its, rages, amasis, taylor, the, longwood, crichton,
# Nearest to with: between, pytheas, ata, emmer, prompting, galore, messengers, moslem,
# Nearest to first: second, the, caterina, mogul, flamenco, miramax, before, tycoon,
# Nearest to zero: three, two, one, approximately, edition, campana, five, six,
# Nearest to their: them, they, own, plastids, shahada, genevieve, themselves, continue,
# Nearest to may: can, would, might, letterboxes, could, will, or, must,
# Nearest to recorded: quill, detain, societas, since, tryin, vcs, album, recognisable,
# Nearest to award: awards, best, academy, nominations, awarded, achievement, medal, nominated,
# Nearest to paris: nantes, ephrem, freeland, workmen, smelted, freiburg, bassoonist, duc,
# Nearest to pope: unraveling, cripps, dray, talib, jozef, rhododendron, contained, squandered,
# Nearest to engineering: cellphones, engineers, electrical, normalize, energetics, espionage, defense, seattle,
# Nearest to shown: shows, henryk, zapata, seen, hailstorm, hypoxic, headingley, damn,
# Nearest to pressure: policy, blood, temperature, tugs, hospitalization, regimen, quantity, austrofascism,
# Nearest to institute: hopkins, institutions, underpinnings, kyd, gamemaster, provides, rebroadcast, interdisciplinary,
# Epoch 3/10 Iteration: 31100 Avg. Training loss: 4.4081 0.1401 sec/batch
# Epoch 3/10 Iteration: 31200 Avg. Training loss: 4.3834 0.1393 sec/batch
# Epoch 3/10 Iteration: 31300 Avg. Training loss: 4.4034 0.1403 sec/batch
# Epoch 3/10 Iteration: 31400 Avg. Training loss: 4.3533 0.1402 sec/batch
# Epoch 3/10 Iteration: 31500 Avg. Training loss: 4.3016 0.1401 sec/batch
# Epoch 3/10 Iteration: 31600 Avg. Training loss: 4.3432 0.1403 sec/batch
# Epoch 3/10 Iteration: 31700 Avg. Training loss: 4.3570 0.1401 sec/batch
# Epoch 3/10 Iteration: 31800 Avg. Training loss: 4.3608 0.1398 sec/batch
# Epoch 3/10 Iteration: 31900 Avg. Training loss: 4.3270 0.1401 sec/batch
# Epoch 3/10 Iteration: 32000 Avg. Training loss: 4.4349 0.1403 sec/batch
# Nearest to over: thousand, pixel, several, cogs, within, stun, federations, spouses,
# Nearest to this: it, which, another, a, fact, that, woolsack, wording,
# Nearest to s: samuel, its, the, of, tabloids, taylor, rages, amasis,
# Nearest to with: between, pytheas, ata, emmer, prompting, accompanying, ide, homogeneous,
# Nearest to first: second, the, caterina, mogul, flamenco, miramax, before, tycoon,
# Nearest to zero: three, two, one, five, six, edition, mega, approximately,
# Nearest to their: them, they, own, plastids, themselves, continue, shahada, do,
# Nearest to may: can, would, might, letterboxes, or, could, will, must,
# Nearest to recorded: detain, quill, societas, since, tryin, recognisable, represented, zipper,
# Nearest to award: awards, best, academy, nominations, awarded, medal, achievement, nominated,
# Nearest to paris: nantes, ephrem, smelted, freeland, workmen, glad, bassoonist, billionaire,
# Nearest to pope: unraveling, dray, cripps, talib, jozef, rhododendron, contained, squandered,
# Nearest to engineering: cellphones, engineers, electrical, normalize, espionage, defense, seattle, energetics,
# Nearest to shown: shows, henryk, seen, zapata, hypoxic, hailstorm, headingley, standout,
# Nearest to pressure: policy, temperature, blood, hospitalization, regimen, tugs, banias, austrofascism,
# Nearest to institute: hopkins, institutions, underpinnings, gamemaster, kyd, provides, rebroadcast, isadore,
# Epoch 3/10 Iteration: 32100 Avg. Training loss: 4.2629 0.1431 sec/batch
# Epoch 3/10 Iteration: 32200 Avg. Training loss: 4.1566 0.1415 sec/batch
# Epoch 3/10 Iteration: 32300 Avg. Training loss: 4.2203 0.1416 sec/batch
# Epoch 3/10 Iteration: 32400 Avg. Training loss: 4.3262 0.1414 sec/batch
# Epoch 3/10 Iteration: 32500 Avg. Training loss: 4.3761 0.1425 sec/batch
# Epoch 3/10 Iteration: 32600 Avg. Training loss: 4.4082 0.1416 sec/batch
# Epoch 3/10 Iteration: 32700 Avg. Training loss: 4.3800 0.1416 sec/batch
# Epoch 3/10 Iteration: 32800 Avg. Training loss: 4.4598 0.1403 sec/batch
# Epoch 3/10 Iteration: 32900 Avg. Training loss: 4.4511 0.1398 sec/batch
# Epoch 3/10 Iteration: 33000 Avg. Training loss: 4.4353 0.1408 sec/batch
# Nearest to over: thousand, pixel, cogs, stun, abdal, donna, within, federations,
# Nearest to this: it, which, another, a, fact, mariette, that, woolsack,
# Nearest to s: samuel, the, tabloids, its, of, unrequited, crichton, taylor,
# Nearest to with: between, pytheas, galore, ata, stamens, prompting, eurystheus, messengers,
# Nearest to first: the, second, caterina, mogul, flamenco, before, miramax, heiress,
# Nearest to zero: three, approximately, the, campana, two, million, mega, edition,
# Nearest to their: them, they, own, plastids, shahada, themselves, his, continue,
# Nearest to may: can, would, might, letterboxes, could, will, july, must,
# Nearest to recorded: quill, detain, societas, since, tryin, album, zipper, recognisable,
# Nearest to award: awards, best, academy, awarded, medal, nominations, achievement, nominated,
# Nearest to paris: nantes, ephrem, freeland, smelted, workmen, freiburg, glad, billionaire,
# Nearest to pope: unraveling, dray, cripps, rhododendron, talib, jozef, xii, squandered,
# Nearest to engineering: cellphones, engineers, electrical, normalize, espionage, inventor, energetics, birkbeck,
# Nearest to shown: shows, seen, hailstorm, henryk, zapata, hypoxic, pasha, headingley,
# Nearest to pressure: policy, temperature, blood, regimen, hospitalization, tugs, hands, banias,
# Nearest to institute: hopkins, underpinnings, institutions, gamemaster, kyd, rebroadcast, trustees, isadore,
# Epoch 3/10 Iteration: 33100 Avg. Training loss: 4.3852 0.1426 sec/batch
# Epoch 3/10 Iteration: 33200 Avg. Training loss: 4.2204 0.1413 sec/batch
# Epoch 3/10 Iteration: 33300 Avg. Training loss: 4.3930 0.1416 sec/batch
# Epoch 3/10 Iteration: 33400 Avg. Training loss: 4.4023 0.1418 sec/batch
# Epoch 3/10 Iteration: 33500 Avg. Training loss: 4.3933 0.1407 sec/batch
# Epoch 3/10 Iteration: 33600 Avg. Training loss: 4.3551 0.1411 sec/batch
# Epoch 3/10 Iteration: 33700 Avg. Training loss: 4.4289 0.1413 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

# %%
with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
